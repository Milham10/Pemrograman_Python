# %% [markdown]
# <a href="https://colab.research.google.com/github/Milham10/Pemrograman_Python/blob/main/PYTHON_GRAFIK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
  #frek = frekuensi (MHz)
  #tipe = urban, suburban, open
  #ht = tinggi tower (meter)
  #hr = tinggi user (meter)
  #d = jarak (meter)
  if frek in range(150,1501):
      Ca=69.55
      Cb=26.16
  elif frek in range(1501,2001):
      Ca=46.3
      Cb=33.9
    
  if tipe=='urban' :
      Cm=0
  elif tipe=='suburban' :
      Cm= -2*((np.log10((frek/28)**2))-5.4)
  elif tipe=='open' :
      Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
  else :
      Cm='tipe salah'
    
  ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
  Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
  return Lp

# %%
f=1800 #MHz
loc1='urban'
loc2='suburban'
loc3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
print(d)
# Out:
# [279 510 544 260 363 467 530 262 606 428 362 451 308 265 284 668 289 493
#  608 338 523 293 385 470 455 368 570 509 370 482 510 229 439 313 637 429
#  517 579 304 210 677 556 657 618 268 270 675 562 261 405 516 646 245 365
#  453 239 288 547 441 319 218 379 280 286 311 311 472 223 505 530 347 653
#  433 626 568 617 224 410 679 496 374 692 296 613 537 359 593 491 692 646
#  410 567 329 694 466 577 411 685 434 551 297 382 478 446 420 516 292 449
#  630 222 295 525 251 331 264 630 687 411 586 288 590 381 478 375 590 532
#  566 504 678 227 268 353 570 464 445 470 256 447 652 262 268 573 362 697
#  240 315 215 209 617 592 593 646 448 553 673 442 416 570 306 242 360 562
#  294 209 586 545 607 591 438 292 609 207 301 537 229 235 569 459 283 445
#  678 521 617 558 542 303 231 208 523 226 384 431 264 460 394 477 320 516
#  415 573]

# %%
LpUrban=cos(f,loc1,tower,user,d)
LpSuburban=cos(f,loc2,tower,user,d)
LpOpen=cos(f,loc3,tower,user,d)

# %%
plt.figure()
plt.plot(d,LpUrban,'r-x',label='Urban')
plt.plot(d,LpSuburban,'g-+',label='Suburban')
plt.plot(d,LpOpen,'b-^', label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r',label='Urban')
plt.plot(d_sort,Suburban_sort,'g',label='Suburban')
plt.plot(d_sort,Open_sort,'b',label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
f1=700 #MHz
f2=900 #MHz
f3=1800 #MHz
loc1='urban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban=cos(f1,loc1,tower,user,d)
LpSuburban=cos(f2,loc1,tower,user,d)
LpOpen=cos(f3,loc1,tower,user,d)

# %%
plt.figure()
plt.plot(d,LpUrban,'r-x',label='700Mhz')
plt.plot(d,LpSuburban,'g-+',label='900Mhz')
plt.plot(d,LpOpen,'b-^', label='1800Mhz')
plt.legend()
plt.title('model urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r',label='700Mhz')
plt.plot(d_sort,Suburban_sort,'g',label='900Mhz')
plt.plot(d_sort,Open_sort,'b',label='1800Mhz')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
